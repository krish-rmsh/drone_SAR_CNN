# %%
# Claims to be faster than mobilenet 
# https://gist.github.com/imbibekk/fde87f0a57f351d28e182828d118c98b # No direct keras implementation

# %%
import tensorflow as tf

from tensorflow.keras.layers import Input , Dense , Flatten , GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from pathlib import Path
from tensorflow.keras import layers
from keras_preprocessing.image import ImageDataGenerator
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, SeparableConv2D,BatchNormalization,concatenate, Input,AveragePooling2D
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.models import Model


def _DenseLayer(x,num_input_features, growth_rate, bottleneck_width, drop_rate):

    growth_rate = int(growth_rate / 2)
    inter_channel = int(growth_rate  * bottleneck_width / 4) * 4 

    if inter_channel > num_input_features / 2:
        inter_channel = int(num_input_features / 8) * 4
        print('adjust inter_channel to ',inter_channel)


    left = Conv2D(inter_channel, (1, 1), padding='same')(x)
    left = BatchNormalization()(x)
    left = Activation('relu')(x)

    left = Conv2D(growth_rate, (3, 3), padding='same')(x)
    left = BatchNormalization()(x)
    left = Activation('relu')(x)

    right = Conv2D(inter_channel, (1, 1), padding='same')(x)
    right = BatchNormalization()(x)
    right = Activation('relu')(x)

    right = Conv2D(growth_rate, (3, 3), padding='same')(x)
    right = BatchNormalization()(x)
    right = Activation('relu')(x)

    right = Conv2D(growth_rate, (3, 3), padding='same')(x)
    right = BatchNormalization()(x)
    right = Activation('relu')(x)
    
    out = concatenate([left,x,right],axis=3)

    return out


def basic_conv(x, output_channels, kernel_size, stride):
    x = Conv2D(output_channels, (kernel_size, kernel_size),strides=(stride,stride), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x


def _DenseBlock(x, num_layers, num_input_features, bn_size, growth_rate, drop_rate):
        
        for i in range(num_layers):
                x = _DenseLayer(x, num_input_features + i * growth_rate, growth_rate, bn_size, drop_rate)

        return x



def _StemBlock(x, num_init_features):

    num_stem_features = int(num_init_features/2)
    
    out = basic_conv(x, num_init_features, kernel_size=3, stride=2)
    branch2 = basic_conv(out, num_init_features, kernel_size=1, stride=1)
    branch2 = basic_conv(branch2, num_init_features, kernel_size=3, stride=2)
    branch1 = MaxPooling2D()(out)
    out = concatenate([branch1,branch2],axis=3)
    out = basic_conv(out, num_init_features, kernel_size=1, stride=1)
    
    return out
    
def PeleeNet(growth_rate=32, block_config=[3, 4, 8, 6],num_init_features=32, bottleneck_width=[1, 2, 4, 4], drop_rate=0.05, num_classes=10):


    if type(growth_rate) is list:
            growth_rates = growth_rate
            assert len(growth_rates) == 4, 'The growth rate must be the list and the size must be 4'
    else:
            growth_rates = [growth_rate] * 4

    if type(bottleneck_width) is list:
            bottleneck_widths = bottleneck_width
            assert len(bottleneck_widths) == 4, 'The bottleneck width must be the list and the size must be 4'
    else:
            bottleneck_widths = [bottleneck_width] * 4

    inp = Input((32, 32, 3))
    stem_block =  _StemBlock(inp, num_init_features)
    num_features = num_init_features

    for i, num_layers in enumerate(block_config):
        
            block = _DenseBlock(stem_block,num_layers=num_layers, num_input_features=num_features,
                                bn_size=bottleneck_widths[i], growth_rate=growth_rates[i], drop_rate=drop_rate)
            
            num_features = num_features + num_layers * growth_rates[i]

            block = basic_conv(block, num_features, kernel_size=1, stride=1)
            
            if i != len(block_config) - 1:
                block = AveragePooling2D()(block)
                num_features = num_features
                stem_block = block
            else:
                stem_block =  block
                
    block = Flatten()(block)
    block = Dropout(drop_rate)(block)
#     block = Dense(num_classes, activation='softmax')(block)
    block = Dense(1, activation='sigmoid')(block)

    model = Model(inp,block)
    return model



# if __name__ == '__main__':
#         # test the model
#         model = PeleeNet()
#         model.summary()

# %%
model = PeleeNet()

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_226 (Conv2D)            (None, 16, 16, 32)   896         ['input_3[0][0]']
#
#  batch_normalization_226 (Batch  (None, 16, 16, 32)  128         ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_226 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_226[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 16, 16, 32)   1056        ['activation_226[0][0]']
#
#  batch_normalization_227 (Batch  (None, 16, 16, 32)  128         ['conv2d_227[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_227[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 8, 8, 32)     9248        ['activation_227[0][0]']
#
#  batch_normalization_228 (Batch  (None, 8, 8, 32)    128         ['conv2d_228[0][0]']
#  Normalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 32)    0           ['activation_226[0][0]']
#
#  activation_228 (Activation)    (None, 8, 8, 32)     0           ['batch_normalization_228[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 8, 8, 64)     0           ['max_pooling2d_2[0][0]',
#                                                                   'activation_228[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 8, 8, 32)     2080        ['concatenate_44[0][0]']
#
#  batch_normalization_229 (Batch  (None, 8, 8, 32)    128         ['conv2d_229[0][0]']
#  Normalization)
#
#  activation_229 (Activation)    (None, 8, 8, 32)     0           ['batch_normalization_229[0][0]']
#
#  activation_231 (Activation)    (None, 8, 8, 32)     0           ['activation_229[0][0]']
#
#  activation_234 (Activation)    (None, 8, 8, 32)     0           ['activation_229[0][0]']
#
#  concatenate_45 (Concatenate)   (None, 8, 8, 96)     0           ['activation_231[0][0]',
#                                                                   'activation_229[0][0]',
#                                                                   'activation_234[0][0]']
#
#  activation_236 (Activation)    (None, 8, 8, 96)     0           ['concatenate_45[0][0]']
#
#  activation_239 (Activation)    (None, 8, 8, 96)     0           ['concatenate_45[0][0]']
#
#  concatenate_46 (Concatenate)   (None, 8, 8, 288)    0           ['activation_236[0][0]',
#                                                                   'concatenate_45[0][0]',
#                                                                   'activation_239[0][0]']
#
#  activation_241 (Activation)    (None, 8, 8, 288)    0           ['concatenate_46[0][0]']
#
#  activation_244 (Activation)    (None, 8, 8, 288)    0           ['concatenate_46[0][0]']
#
#  concatenate_47 (Concatenate)   (None, 8, 8, 864)    0           ['activation_241[0][0]',
#                                                                   'concatenate_46[0][0]',
#                                                                   'activation_244[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 8, 8, 128)    110720      ['concatenate_47[0][0]']
#
#  batch_normalization_245 (Batch  (None, 8, 8, 128)   512         ['conv2d_245[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 8, 8, 128)    0           ['batch_normalization_245[0][0]']
#
#  average_pooling2d_6 (AveragePo  (None, 4, 4, 128)   0           ['activation_245[0][0]']
#  oling2D)
#
#  activation_247 (Activation)    (None, 4, 4, 128)    0           ['average_pooling2d_6[0][0]']
#
#  activation_250 (Activation)    (None, 4, 4, 128)    0           ['average_pooling2d_6[0][0]']
#
#  concatenate_48 (Concatenate)   (None, 4, 4, 384)    0           ['activation_247[0][0]',
#                                                                   'average_pooling2d_6[0][0]',
#                                                                   'activation_250[0][0]']
#
#  activation_252 (Activation)    (None, 4, 4, 384)    0           ['concatenate_48[0][0]']
#
#  activation_255 (Activation)    (None, 4, 4, 384)    0           ['concatenate_48[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 4, 4, 1152)   0           ['activation_252[0][0]',
#                                                                   'concatenate_48[0][0]',
#                                                                   'activation_255[0][0]']
#
#  activation_257 (Activation)    (None, 4, 4, 1152)   0           ['concatenate_49[0][0]']
#
#  activation_260 (Activation)    (None, 4, 4, 1152)   0           ['concatenate_49[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 4, 4, 3456)   0           ['activation_257[0][0]',
#                                                                   'concatenate_49[0][0]',
#                                                                   'activation_260[0][0]']
#
#  activation_262 (Activation)    (None, 4, 4, 3456)   0           ['concatenate_50[0][0]']
#
#  activation_265 (Activation)    (None, 4, 4, 3456)   0           ['concatenate_50[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 4, 4, 10368)  0           ['activation_262[0][0]',
#                                                                   'concatenate_50[0][0]',
#                                                                   'activation_265[0][0]']
#
#  conv2d_266 (Conv2D)            (None, 4, 4, 256)    2654464     ['concatenate_51[0][0]']
#
#  batch_normalization_266 (Batch  (None, 4, 4, 256)   1024        ['conv2d_266[0][0]']
#  Normalization)
#
#  activation_266 (Activation)    (None, 4, 4, 256)    0           ['batch_normalization_266[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 2, 2, 256)   0           ['activation_266[0][0]']
#  oling2D)
#
#  activation_268 (Activation)    (None, 2, 2, 256)    0           ['average_pooling2d_7[0][0]']
#
#  activation_271 (Activation)    (None, 2, 2, 256)    0           ['average_pooling2d_7[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 2, 2, 768)    0           ['activation_268[0][0]',
#                                                                   'average_pooling2d_7[0][0]',
#                                                                   'activation_271[0][0]']
#
#  activation_273 (Activation)    (None, 2, 2, 768)    0           ['concatenate_52[0][0]']
#
#  activation_276 (Activation)    (None, 2, 2, 768)    0           ['concatenate_52[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 2, 2, 2304)   0           ['activation_273[0][0]',
#                                                                   'concatenate_52[0][0]',
#                                                                   'activation_276[0][0]']
#
#  activation_278 (Activation)    (None, 2, 2, 2304)   0           ['concatenate_53[0][0]']
#
#  activation_281 (Activation)    (None, 2, 2, 2304)   0           ['concatenate_53[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 2, 2, 6912)   0           ['activation_278[0][0]',
#                                                                   'concatenate_53[0][0]',
#                                                                   'activation_281[0][0]']
#
#  activation_283 (Activation)    (None, 2, 2, 6912)   0           ['concatenate_54[0][0]']
#
#  activation_286 (Activation)    (None, 2, 2, 6912)   0           ['concatenate_54[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 2, 2, 20736)  0           ['activation_283[0][0]',
#                                                                   'concatenate_54[0][0]',
#                                                                   'activation_286[0][0]']
#
#  activation_288 (Activation)    (None, 2, 2, 20736)  0           ['concatenate_55[0][0]']
#
#  activation_291 (Activation)    (None, 2, 2, 20736)  0           ['concatenate_55[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 2, 2, 62208)  0           ['activation_288[0][0]',
#                                                                   'concatenate_55[0][0]',
#                                                                   'activation_291[0][0]']
#
#  activation_293 (Activation)    (None, 2, 2, 62208)  0           ['concatenate_56[0][0]']
#
#  activation_296 (Activation)    (None, 2, 2, 62208)  0           ['concatenate_56[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 2, 2, 186624  0           ['activation_293[0][0]',
#                                 )                                 'concatenate_56[0][0]',
#                                                                   'activation_296[0][0]']
#
#  activation_298 (Activation)    (None, 2, 2, 186624  0           ['concatenate_57[0][0]']
#                                 )
#
#  activation_301 (Activation)    (None, 2, 2, 186624  0           ['concatenate_57[0][0]']
#                                 )
#
#  concatenate_58 (Concatenate)   (None, 2, 2, 559872  0           ['activation_298[0][0]',
#                                 )                                 'concatenate_57[0][0]',
#                                                                   'activation_301[0][0]']
#
#  activation_303 (Activation)    (None, 2, 2, 559872  0           ['concatenate_58[0][0]']
#                                 )
#
#  activation_306 (Activation)    (None, 2, 2, 559872  0           ['concatenate_58[0][0]']
#                                 )
#
#  concatenate_59 (Concatenate)   (None, 2, 2, 167961  0           ['activation_303[0][0]',
#                                 6)                                'concatenate_58[0][0]',
#                                                                   'activation_306[0][0]']
#
#  conv2d_307 (Conv2D)            (None, 2, 2, 512)    859963904   ['concatenate_59[0][0]']
#
#  batch_normalization_307 (Batch  (None, 2, 2, 512)   2048        ['conv2d_307[0][0]']
#  Normalization)
#
#  activation_307 (Activation)    (None, 2, 2, 512)    0           ['batch_normalization_307[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 1, 1, 512)   0           ['activation_307[0][0]']
#  oling2D)
#
#  activation_309 (Activation)    (None, 1, 1, 512)    0           ['average_pooling2d_8[0][0]']
#
#  activation_312 (Activation)    (None, 1, 1, 512)    0           ['average_pooling2d_8[0][0]']
#
#  concatenate_60 (Concatenate)   (None, 1, 1, 1536)   0           ['activation_309[0][0]',
#                                                                   'average_pooling2d_8[0][0]',
#                                                                   'activation_312[0][0]']
#
#  activation_314 (Activation)    (None, 1, 1, 1536)   0           ['concatenate_60[0][0]']
#
#  activation_317 (Activation)    (None, 1, 1, 1536)   0           ['concatenate_60[0][0]']
#
#  concatenate_61 (Concatenate)   (None, 1, 1, 4608)   0           ['activation_314[0][0]',
#                                                                   'concatenate_60[0][0]',
#                                                                   'activation_317[0][0]']
#
#  activation_319 (Activation)    (None, 1, 1, 4608)   0           ['concatenate_61[0][0]']
#
#  activation_322 (Activation)    (None, 1, 1, 4608)   0           ['concatenate_61[0][0]']
#
#  concatenate_62 (Concatenate)   (None, 1, 1, 13824)  0           ['activation_319[0][0]',
#                                                                   'concatenate_61[0][0]',
#                                                                   'activation_322[0][0]']
#
#  activation_324 (Activation)    (None, 1, 1, 13824)  0           ['concatenate_62[0][0]']
#
#  activation_327 (Activation)    (None, 1, 1, 13824)  0           ['concatenate_62[0][0]']
#
#  concatenate_63 (Concatenate)   (None, 1, 1, 41472)  0           ['activation_324[0][0]',
#                                                                   'concatenate_62[0][0]',
#                                                                   'activation_327[0][0]']
#
#  activation_329 (Activation)    (None, 1, 1, 41472)  0           ['concatenate_63[0][0]']
#
#  activation_332 (Activation)    (None, 1, 1, 41472)  0           ['concatenate_63[0][0]']
#
#  concatenate_64 (Concatenate)   (None, 1, 1, 124416  0           ['activation_329[0][0]',
#                                 )                                 'concatenate_63[0][0]',
#                                                                   'activation_332[0][0]']
#
#  activation_334 (Activation)    (None, 1, 1, 124416  0           ['concatenate_64[0][0]']
#                                 )
#
#  activation_337 (Activation)    (None, 1, 1, 124416  0           ['concatenate_64[0][0]']
#                                 )
#
#  concatenate_65 (Concatenate)   (None, 1, 1, 373248  0           ['activation_334[0][0]',
#                                 )                                 'concatenate_64[0][0]',
#                                                                   'activation_337[0][0]']
#
#  conv2d_338 (Conv2D)            (None, 1, 1, 704)    262767296   ['concatenate_65[0][0]']
#
#  batch_normalization_338 (Batch  (None, 1, 1, 704)   2816        ['conv2d_338[0][0]']
#  Normalization)
#
#  activation_338 (Activation)    (None, 1, 1, 704)    0           ['batch_normalization_338[0][0]']
#  flatten_2 (Flatten)            (None, 704)          0           ['activation_338[0][0]']
#
#  dropout_2 (Dropout)            (None, 704)          0           ['flatten_2[0][0]']
#
#  dense_8 (Dense)                (None, 1)            705         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 1,125,517,281
# Trainable params: 1,125,513,825
# Non-trainable params: 3,456
# __________________________________________________________________________________________________

# %%
model2 = Sequential()
model2.add(model)
#model2.add(GlobalAveragePooling2D())
#model2.add(Flatten())
# model2.add(Dense(1024, activation="relu"))
# model2.add(Dense(512, activation="relu"))

# model2.add(Dense(1024, activation="relu"))
# model2.add(Dense(512, activation="relu"))

# model2.add(Dense(1024, activation="relu"))
# model2.add(Dense(512, activation="relu"))



#model2.add(Dense(1, activation="sigmoid" , name="classification"))

# %%
model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_2 (Functional)        (None, 1)                 1125517281
#
# =================================================================
# Total params: 1,125,517,281
# Trainable params: 1,125,513,825
# Non-trainable params: 3,456
# _________________________________________________________________

# %%
result_root = r'/Users/krish/ljmu/3.results/29112022-peelenet/'
Path(result_root).mkdir(parents=True, exist_ok=True)

# %%
root_path =  r'/Users/krish/ljmu/1.data/afo/'
actual_train = pd.read_csv(root_path+'images/train.csv')

# %%
actual_train['humans'] = actual_train.humans.apply(lambda x: str(x))

# %%
train_df, valid_df = train_test_split(actual_train, 
                                   test_size = 0.15, 
                                   random_state = 1998,
                                   stratify = actual_train['humans']) # Stratify makes sure that the subset of training and testing data returned keeps the same class propotion of the main dataframe
print('train', train_df.shape[0], 'validation', valid_df.shape[0])
# Out:
# train 2320 validation 410

# %%
# Rotation_range - random rotation within the angle mentioned
# Random_shifts - shifts 20% at max. to the horizontal and vertical(reduce to 10% as already diverse data)
# Random_flip - random flips 
# fill_mode - fill the blank pixels, when augmenting with the nearest color
datagen = ImageDataGenerator(rotation_range = 360,
                             width_shift_range=0.1, height_shift_range=0.1,
                             #horizontal_flip=True, vertical_flip=True, # Isnt much useful for us
                             brightness_range=[0.5,1.5],
                             rescale=1./255.,fill_mode='nearest')

train_generator = datagen.flow_from_dataframe(dataframe=train_df, x_col = 'file_name', y_col = 'humans', class_mode='binary', target_size=(224 , 224), batch_size=24)
valid_generator = datagen.flow_from_dataframe(dataframe=valid_df, x_col = 'file_name', y_col = 'humans', class_mode='binary', target_size=(224 , 224), batch_size=24)
# Out:
# Found 2320 validated image filenames belonging to 2 classes.
# Found 410 validated image filenames belonging to 2 classes.

# %%
model2.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.004,momentum=0.9), 
            loss='BinaryCrossentropy',
            metrics = ['accuracy'])

model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_2 (Functional)        (None, 1)                 1125517281
#
# =================================================================
# Total params: 1,125,517,281
# Trainable params: 1,125,513,825
# Non-trainable params: 3,456
# _________________________________________________________________

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, min_delta = 0.5)

# %%
class_weight = {0:train_df['humans'].value_counts()[0]/train_df.shape[0],1:train_df['humans'].value_counts()[1]/train_df.shape[0],}

# %%
history = model2.fit(train_generator, validation_data = valid_generator, epochs = 10, class_weight=class_weight,callbacks=[es])
