# %%
# This is just to test if there really exist a text file for every jpg file
# Actually this is a reduntnt test, rather write a condition inyour crawler wher you avoid images where the txt fle is missing.

# %%
import shutil

# %%
# Mac directory
source_dir = r'/Users/krish/ljmu/1.data/swimmers_dataset/training_dataset/'
destination_dir = r'/Users/krish/ljmu/1.data/swimmers_dataset/krish_train/'

# %%
for i in range(12235):
    source_img = source_dir +str(1+i)+ '.jpg'
    source_txt = source_dir +str(1+i)+'.txt'
    destination = destination_dir
    shutil.copy(source_img,destination)
    shutil.copy(source_txt,destination)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
#       3 source_txt = source_dir +str(1+i)+'.txt'
#       4 destination = destination_dir
# ----> 5 shutil.copy(source_img,destination)
#       6 shutil.copy(source_txt,destination)
#
# File ~/opt/anaconda3/lib/python3.9/shutil.py:427, in copy(src, dst, follow_symlinks)
#     425 if os.path.isdir(dst):
#     426     dst = os.path.join(dst, os.path.basename(src))
# --> 427 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     428 copymode(src, dst, follow_symlinks=follow_symlinks)
#     429 return dst
#
# File ~/opt/anaconda3/lib/python3.9/shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc:
#     265         try:
#     266             with open(dst, 'wb') as fdst:
# ...

# %%
# Its good that the loop stopped here, after 1990 all images weer not in the drone format

# %%
for i in range(2144,2172):
    source_img = source_dir +str(1+i)+'.jpg'
    source_txt = source_dir+str(1+i)+'.txt'
    destination = destination_dir
    shutil.copy(source_img,destination)
    shutil.copy(source_txt,destination)

# %%
list(range(2,5))
# Out:
# [2, 3, 4]

# %%
for i in range(2320,2429):
    source_img = source_dir +str(1+i)+'.jpg'
    source_txt = source_dir+str(1+i)+'.txt'
    destination = destination_dir
    shutil.copy(source_img,destination)
    shutil.copy(source_txt,destination)

# %%
for i in range(2550,3118):
    source_img = source_dir +str(1+i)+'.jpg'
    source_txt = source_dir+str(1+i)+'.txt'
    destination = destination_dir
    shutil.copy(source_img,destination)
    shutil.copy(source_txt,destination)

# %%
for i in range(3187,3675):
    source_img = source_dir +str(1+i)+'.jpg'
    source_txt = source_dir+str(1+i)+'.txt'
    destination = destination_dir
    shutil.copy(source_img,destination)
    shutil.copy(source_txt,destination)

# %%
for i in range(4154,4259):
    source_img = source_dir +str(1+i)+'.jpg'
    source_txt = source_dir+str(1+i)+'.txt'
    destination = destination_dir
    shutil.copy(source_img,destination)
    shutil.copy(source_txt,destination)

# %%
for i in range(4396,6572):
    source_img = source_dir +str(1+i)+'.jpg'
    source_txt = source_dir+str(1+i)+'.txt'
    destination = destination_dir
    shutil.copy(source_img,destination)
    shutil.copy(source_txt,destination)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
#       3 source_txt = source_dir+str(1+i)+'.txt'
#       4 destination = destination_dir
# ----> 5 shutil.copy(source_img,destination)
#       6 shutil.copy(source_txt,destination)
#
# File ~/opt/anaconda3/lib/python3.9/shutil.py:427, in copy(src, dst, follow_symlinks)
#     425 if os.path.isdir(dst):
#     426     dst = os.path.join(dst, os.path.basename(src))
# --> 427 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     428 copymode(src, dst, follow_symlinks=follow_symlinks)
#     429 return dst
#
# File ~/opt/anaconda3/lib/python3.9/shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc:
#     265         try:
#     266             with open(dst, 'wb') as fdst:
# ...

# %%
# 5000 series is random
for i in range(5014,6572):
    source_img = source_dir +str(1+i)+'.jpg'
    source_txt = source_dir+str(1+i)+'.txt'
    destination = destination_dir
    shutil.copy(source_img,destination)
    shutil.copy(source_txt,destination)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [39], in <cell line: 2>()
#       4 source_txt = source_dir+str(1+i)+'.txt'
#       5 destination = destination_dir
# ----> 6 shutil.copy(source_img,destination)
#       7 shutil.copy(source_txt,destination)
#
# File ~/opt/anaconda3/lib/python3.9/shutil.py:427, in copy(src, dst, follow_symlinks)
#     425 if os.path.isdir(dst):
#     426     dst = os.path.join(dst, os.path.basename(src))
# --> 427 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     428 copymode(src, dst, follow_symlinks=follow_symlinks)
#     429 return dst
#
# File ~/opt/anaconda3/lib/python3.9/shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc:
#     265         try:
#     266             with open(dst, 'wb') as fdst:
# ...

# %%
from os.path import exists

# %%
# For the remaing 07/11/22
exception = [6601,6359,9861,12228,12234,12235,130478,130486,130583]+list(range(130314,130478))+list(range(130119,130133))
exception = exception + list(range(130595,130608)) + list(range(130629,130639)) + list(range(130643,130651))
exception = exception + list(range(130655,130663)) + list(range(130666,130674)) + list(range(130678,130685))
exception = exception + list(range(130710,130715)) + list(range(130698,130705)) + list(range(130688,130694))

# %%
for i in range(5014,130749):
    image_path = source_dir+str(i)+'.jpg'
    if (exists(image_path)) and (not(i in exception)):
        print(i)
        source_img = image_path
        source_txt = source_dir+str(i)+'.txt'
        destination = destination_dir
        shutil.copy(source_img,destination)
        shutil.copy(source_txt,destination)
# Out:
# 5014
# 5016
# 5020
# 5026
# 5036
# 5059
# 5076
# 5077
# 5120
# 5148
# 5151
# 5154
# 5156
# 5178
# 5203
# 5211
# 5235
# 5240
# 5248
# 5258
# 5267
# 5302
# 5320
# 5321
# 5326
# 5342
# 5349
# 5361
# 5378
# 5400
# 5402
# 5408
# 5423
# 5441
# 5469
# 5475
# 5487
# 5490
# 5495
# 5502
# 5512
# 5514
# 5527
# 5555
# 5569
# 5574
# 5577
# 5589
# 5603
# 5607
# 5625
# 5684
# 5705
# 5708
# 5711
# 5723
# 5732
# 5755
# 5791
# 5838
# 5851
# 5858
# 5859
# 5861
# 5880
# 5886
# 5926
# 5936
# 5941
# 5972
# 5995
# 6012
# 6025
# 6041
# 6046
# 6113
# 6128
# 6129
# 6133
# 6135
# 6155
# 6169
# 6182
# 6185
# 6205
# 6211
# 6212
# 6213
# 6227
# 6266
# 6291
# 6295
# 6306
# 6311
# 6321
# 6332
# 6335
# 6367
# 6368
# 6377
# 6391
# 6416
# 6421
# 6442
# 6449
# 6461
# 6462
# 6467
# 6482
# 6484
# 6489
# 6494
# 6495
# 6498
# 6505
# 6507
# 6509
# 6511
# 6556
# 6567
# 6571
# 6635
# 6645
# 6658
# 6667
# 6671
# 6673
# 6676
# 6680
# 6695
# 6700
# 6706
# 6724
# 6725
# 6726
# 6772
# 6773
# 6788
# 6840
# 6865
# 6881
# 6892
# ...

# %% [markdown]
# ## Dataframe for the mobilenet training

# %%
# Columns of a dtaframe: Name, if label, number of labels
import pandas as pd
import glob

# %%
# This snippet can be used for the number of objects
with open(r'D:\swimmers_dataset\krish_train\86.txt','r') as fp:
    print(len(fp.readlines()))
# Out:
# 2

# %%
df_basic = pd.DataFrame(columns=['Name','contains_human','number_of_human'])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_basic = pd.DataFrame(columns=['Name','contains_human','number_of_human'])
for annotation in glob.glob('D:\swimmers_dataset\krish_train\*.txt'):
    with open(annotation,'r') as fp:
        number_of_human = len(fp.readlines())
    if number_of_human:
        contains_human = 1
    else:
        contains_human = 0
    annotation = os.path.splitext(annotation)[0]+'.jpg' 
    ser_app = pd.Series([annotation,contains_human,number_of_human],index = ['Name','contains_human','number_of_human'])
    df_basic = df_basic.append(ser_app, ignore_index=True)

# %%
df_basic
# Out:
#                                           Name contains_human number_of_human
# 0        D:\swimmers_dataset\krish_train\1.jpg              1               1
# 1       D:\swimmers_dataset\krish_train\10.jpg              1               1
# 2      D:\swimmers_dataset\krish_train\100.jpg              1               2
# 3     D:\swimmers_dataset\krish_train\1000.jpg              1               2
# 4     D:\swimmers_dataset\krish_train\1001.jpg              1               3
# ...                                        ...            ...             ...
# 3735   D:\swimmers_dataset\krish_train\995.jpg              1               2
# 3736   D:\swimmers_dataset\krish_train\996.jpg              1               2
# 3737   D:\swimmers_dataset\krish_train\997.jpg              1               2
# 3738   D:\swimmers_dataset\krish_train\998.jpg              1               2
# 3739   D:\swimmers_dataset\krish_train\999.jpg              1               2
#
# [3740 rows x 3 columns]

# %%
df_basic.contains_human.sum()
# Severe class imabaance
df_basic.to_csv('database_for_training.csv')

# %%
df_basic.contains_human.value_counts()
# Out:
# 1    2178
# 0    1562
# Name: contains_human, dtype: int64

# %% [markdown]
# ## Let me try buliding the model with this dataset
# There is nothing wrong in copying code as long as you know the functionality

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # showing and rendering figures
# io related
from skimage.io import imread
import os
from glob import glob
# not needed in Kaggle, but required in Jupyter
# %matplotlib inline 
df_basic = pd.read_csv('database_for_training.csv')

# %%
#df_basic['contains_human'] = df_basic.contains_human.apply(lambda x: np.array([0,1] if x else np.array([1,0]))) # used the qubit format

df_basic['contains_human'] = df_basic.contains_human.apply(lambda x: str(x)) # used the qubit format

# %%
from sklearn.model_selection import train_test_split

train_df, valid_df = train_test_split(df_basic, 
                                   test_size = 0.25, 
                                   random_state = 2018,
                                   stratify = df_basic['contains_human']) # Stratify makes sure that the subset of training and testing data returned keeps the same class propotion of the main dataframe
print('train', train_df.shape[0], 'validation', valid_df.shape[0])
# Out:
# train 2805 validation 935

# %%
from keras import layers
from keras_preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(rescale=1./255.)
train_generator = datagen.flow_from_dataframe(dataframe=train_df, x_col = 'Name', y_col = 'contains_human', class_mode='binary',        target_size=(224 , 224),
        batch_size=32)
valid_generator = datagen.flow_from_dataframe(dataframe=valid_df, x_col = 'Name', y_col = 'contains_human', class_mode='binary',        target_size=(224 , 224),batch_size=32)
# Out:
# Found 2805 validated image filenames belonging to 2 classes.
# Found 935 validated image filenames belonging to 2 classes.

# %%
# Testing how the data is structured
train_generator
image_from_gen = next(valid_generator)

# %%
image_from_gen[0][0].shape

from matplotlib import pyplot as plt
plt.imshow(image_from_gen[0][0])
# So yes, the 224, denotes the size of the output image. But still not sure why this 224 and why the colour hasnt been normalised
# The colour is normalised, the imshow function works with inputs [0,1]

# %% [markdown]
# ### Bring in the model

# %%
#train_generator.shape()

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input , Dense , Flatten , GlobalAveragePooling2D
from tensorflow.keras.models import Sequential

# %%
# i'll be using inception_v3 for this model , along with 2 extra dense layers and the output layer
# (224,224,3) is the default shape for imagent and that actually cant bechanged
mobilenet = tf.keras.applications.mobilenet.MobileNet(input_shape=(224 , 224, 3),
                                           include_top=False, 
                                           weights='imagenet')

model = Sequential()
model.add(mobilenet)
model.add(GlobalAveragePooling2D())
model.add(Flatten())
model.add(Dense(1024, activation="relu"))
model.add(Dense(512, activation="relu"))
model.add(Dense(1, activation="softmax" , name="classification"))

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.0005,momentum=0.9), 
            loss='categorical_crossentropy',
            metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  global_average_pooling2d_9   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  flatten_5 (Flatten)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 1024)              1049600
#
#  dense_5 (Dense)             (None, 512)               524800
#
#  classification (Dense)      (None, 1)                 513
#
# ...
# Total params: 4,803,777
# Trainable params: 4,781,889
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
history = model.fit(train_generator ,validation_data = valid_generator, epochs = 5)
# Out:
# Epoch 1/5
# 88/88 [==============================] - 788s 9s/step - loss: nan - accuracy: 0.5469 - val_loss: nan - val_accuracy: 0.4182
# Epoch 2/5
# 88/88 [==============================] - 671s 8s/step - loss: nan - accuracy: 0.4175 - val_loss: nan - val_accuracy: 0.4182
# Epoch 3/5
# 88/88 [==============================] - 663s 8s/step - loss: nan - accuracy: 0.4175 - val_loss: nan - val_accuracy: 0.4182
# Epoch 4/5
#  6/88 [=>............................] - ETA: 9:54 - loss: nan - accuracy: 0.4010
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [74], in <cell line: 1>()
# ----> 1 history = model.fit(train_generator ,validation_data = valid_generator, epochs = 5)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ...

# %%
datagen = ImageDataGenerator(rescale=1./255.)
train_generator = datagen.flow_from_dataframe(dataframe=train_df, x_col = 'Name', y_col = 'contains_human', class_mode='binary',        target_size=(500 , 500),
        batch_size=32)
valid_generator = datagen.flow_from_dataframe(dataframe=valid_df, x_col = 'Name', y_col = 'contains_human', class_mode='binary',        target_size=(500 , 500),batch_size=32)
# Out:
# Found 2805 validated image filenames belonging to 2 classes.
# Found 935 validated image filenames belonging to 2 classes.

# %%
# Testing how the data is structured
train_generator
image_from_gen = next(valid_generator)

# %%
image_from_gen[0][0].shape

from matplotlib import pyplot as plt
plt.imshow(image_from_gen[0][0])
# So yes, the 224, denotes the size of the output image. But still not sure why this 224 and why the colour hasnt been normalised

# %% [markdown]
# ## Next steps as guided by Sharma,
# Divide the image into smaller fragments and then feed into the model. But this wouldnt work, as there arent any specific features unique to the swimmer. Have to think of feeding the full image along with the divided images, like an ensembe of models to get the prediction.
